# %% [markdown]
# # Notebook 01 — Table 1: Monthly Out-of-Sample Value-Weighted Cluster Returns
#
# **Data read directly from:**
# ```
# Results/cluster_month_panels_K_50/cluster_month_panel_K_50_lambda_1000000.csv
# ```
# The path is resolved automatically via the symlink created in notebook 00.
#
# **Cluster ranking from:** `data/Cluster_Ranking.csv`
# (`lambda_1000000` column maps raw cluster IDs 0–49 → official labels L01–L50)
#
# **Key column used:** `r_t1_wmean` — value-weighted excess return one month ahead
# of the cluster formation date (positions formed end of month t, return at t+1).
#
# **Output:**
# - `output/tables/Table1_Cluster_Returns.csv / .tex`
# - `output/figures/Table1_Bar_Chart.pdf / .png`

# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, REPO_ROOT)

from utils.data_utils import (
    load_cluster_panel,      # reads from Results/ via symlink
    load_cluster_ranking,    # reads data/Cluster_Ranking.csv
    pivot_and_rank,          # pivot r_t1_wmean, apply official ranking
    ann_sharpe, max_dd, calmar, var95,
    nw_tstat, stars,
    save_table, save_figure,
)

plt.rcParams.update({
    "font.family": "serif", "font.size": 10,
    "axes.spines.top": False, "axes.spines.right": False,
    "figure.dpi": 150,
})
NW_LAGS = 3
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [30], line 10
#       7 REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
#       8 sys.path.insert(0, REPO_ROOT)
# ---> 10 from utils.data_utils import (
#      11     load_cluster_panel,      # reads from Results/ via symlink
#      12     load_cluster_ranking,    # reads data/Cluster_Ranking.csv
#      13     pivot_and_rank,          # pivot r_t1_wmean, apply official ranking
#      14     ann_sharpe, max_dd, calmar, var95,
#      15     nw_tstat, stars,
#      16     save_table, save_figure,
#      17 )
#      19 plt.rcParams.update({
#      20     "font.family": "serif", "font.size": 10,
#      21     "axes.spines.top": False, "axes.spines.right": False,
#      22     "figure.dpi": 150,
#      23 })
#      24 NW_LAGS = 3
#
# ...
